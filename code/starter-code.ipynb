# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# as well as an

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid') # seaborn color palette

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
df_sat17 = pd.read_csv('./../data/sat_2017.csv')
df_act17 = pd.read_csv('./../data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
df_sat17.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
df_act17.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %% [markdown]
# Below, I check if there is any null items in different columns of the data files.

# %%
df_sat17.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
df_sat17.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %% [markdown]
# Here, I check if there is any typo in the data file for ACT.

# %%
df_act17[['Composite']].tail(10)
# Out:
#    Composite
# 42      21.8
# 43      19.8
# 44      20.7
# 45      20.3
# 46      23.6
# 47      23.8
# 48      21.9
# 49      20.4
# 50      20.5
# 51     20.2x

# %% [markdown]
# Statistical parameters of the data:

# %%
df_sat17.describe().T
# Out:
#                                     count         mean        std    min  \
# Evidence-Based Reading and Writing   51.0   569.117647  45.666901  482.0
# Math                                 51.0   547.627451  84.909119   52.0
# Total                                51.0  1126.098039  92.494812  950.0
#
#                                        25%     50%     75%     max
# Evidence-Based Reading and Writing   533.5   559.0   613.0   644.0
# Math                                 522.0   548.0   599.0   651.0
# Total                               1055.5  1107.0  1212.0  1295.0

# %%
df_act17.describe().T
# Out:
#          count       mean       std   min     25%    50%     75%   max
# English   52.0  20.919231  2.332132  16.3  19.000  20.55  23.300  25.5
# Math      52.0  21.173077  1.963602  18.0  19.400  20.90  23.100  25.3
# Reading   52.0  22.001923  2.048672  18.1  20.475  21.70  24.125  26.0
# Science   52.0  21.040385  3.151113   2.3  19.900  21.15  22.525  24.9

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer: The SAT data file represents the breakdown of the average SAT score in each state according to the 2017 SAT annual report. For each state, the data describe the participation rate, average scores of Math and Reading & Writing, and the average total score of the SAT exam condcuted in 2017.
#
# The ACT data file represents the ACT state averages for the class of 2017. For each state, the average score of each section of the ACT exam (English, Math, Reading, and Science), the average of the composite score, and the participation rate are reported. In addition, the national average scores are given too.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer: Since there is no null entry in either of the data sets (SAT and ACT), the data look complete.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer: In the SAT exam, the scores of each section should be in the range of 200-800 and th total score ranges between 400 and 1600. Taking look at the results of .describe() method, it appears that except the minimum score for Math, the other values make sense and they are within the range of accepted values. Checking with the source of data, it is clear that the Math score for the state of Maryland is 524 and not 52 and this should be corrected in the dataframe.
#
# In the ACT exam, each section and the overall composite score are scored between 1 and 36. The min and max values of the given data file lie between this range and so all the data entries appear to be correctly entered. However, a closer look shows that the minimum value for ACT sciecne score is too low. By inspecting the source of data, it becomes clear that there is another typo here and the correct average score for science in the state of Maryland is 23.2 (not 2.3). This issue should be corrected too.

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
# Correcting the value of Math score for Maryland
math_min_index = df_sat17[df_sat17.Math == df_sat17.Math.min()].index
df_sat17.loc[math_min_index, 'Math'] = 524
df_sat17.sort_values(by='Math').head()
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 8   District of Columbia          100%                                 482
# 7               Delaware          100%                                 503
# 12                 Idaho           93%                                 513
# 22              Michigan          100%                                 509
# 9                Florida           83%                                 520
#
#     Math  Total
# 8    468    950
# 7    492    996
# 12   493   1005
# 22   495   1005
# 9    497   1017

# %%
# Correcting the value of Science score for Maryland
science_min_index = df_act17[df_act17.Science == df_act17.Science.min()].index
df_act17.loc[science_min_index, 'Science'] = 23.2
df_act17.sort_values(by='Science').head()
# Out:
#              State Participation  English  Math  Reading  Science Composite
# 29          Nevada          100%     16.3  18.0     18.1     18.2      17.8
# 25     Mississippi          100%     18.2  18.1     18.8     18.8      18.6
# 41  South Carolina          100%     17.5  18.6     19.1     18.9      18.7
# 34  North Carolina          100%     17.8  19.3     19.6     19.3      19.1
# 12          Hawaii           90%     17.8  19.2     19.2     19.3      19.0

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
df_sat17.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
df_act17.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer: The participation rate in both data sets is converted into objects because of the % character. So, by removing % the participation data can be cast into integers. Also, in the ACT data set, the composite scores are reported as objects because of a typo at the last row of the data. The composite score for the state of Wyoming is 20.2 and that additional letter 'x' should be removed to fix the data.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
# Removing the % character from the participation data for the SAT exam

df_sat17['Participation'] = df_sat17['Participation'].map(lambda part_cell: part_cell.replace('%', ''))

df_sat17['Participation'] = df_sat17['Participation'].astype(int)

df_sat17['Participation'].dtypes
# Out:
# dtype('int64')

# %%
# Removing the % character from the participation data for the ACT exam

df_act17['Participation'] = df_act17['Participation'].map(lambda part_cell: part_cell.replace('%', ''))

df_act17['Participation'] = df_act17['Participation'].astype(int)

df_act17['Participation'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
# Removing the typo (letter x) in the composite score of the ACT exam

def convert_to_float(grade):
    try:
        return float(grade)
    except ValueError:
        return float(grade[:-1])
    
df_act17['Composite'] = df_act17['Composite'].map(convert_to_float)

df_act17.Composite.tail(10)
# Out:
# 42    21.8
# 43    19.8
# 44    20.7
# 45    20.3
# 46    23.6
# 47    23.8
# 48    21.9
# 49    20.4
# 50    20.5
# 51    20.2
# Name: Composite, dtype: float64

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
df_act17.describe().T
# Out:
#                count       mean        std   min     25%    50%      75%  \
# Participation   52.0  65.153846  31.832518   8.0  31.000  68.00  100.000
# English         52.0  20.919231   2.332132  16.3  19.000  20.55   23.300
# Math            52.0  21.173077   1.963602  18.0  19.400  20.90   23.100
# Reading         52.0  22.001923   2.048672  18.1  20.475  21.70   24.125
# Science         52.0  21.442308   1.723351  18.2  19.975  21.30   23.200
# Composite       52.0  21.509615   2.002083  17.8  19.800  21.40   23.600
#
#                  max
# Participation  100.0
# English         25.5
# Math            25.3
# Reading         26.0
# Science         24.9
# Composite       25.5

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
df_sat17.dtypes
# Out:
# State                                 object
# Participation                          int64
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
df_act17.dtypes
# Out:
# State             object
# Participation      int64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
new_columns_sat17 = {
        'State':'state',
        'Participation':'sat_17_participation',
        'Evidence-Based Reading and Writing':'sat_17_reading_and_writing',
        'Math':'sat_17_math',
        'Total':'sat_17_total'
                    }

new_columns_act17 = {
        'State':'state',
        'Participation':'act_17_participation',
        'English':'act_17_english',
        'Math':'act_17_math',
        'Reading':'act_17_reading',
        'Science':'act_17_science',
        'Composite':'act_17_composite'
                    }

df_sat17.rename(columns=new_columns_sat17, inplace=True)
df_act17.rename(columns=new_columns_act17, inplace=True)

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
# Data set of the ACT exam has an unnecessary row which gives the national average of the scores.
# Here I remove that first row.

df_act17 = df_act17.drop(0)
df_act17.reset_index(drop=True, inplace=True)
df_act17.head()
# Out:
#         state  act_17_participation  act_17_english  act_17_math  \
# 0     Alabama                   100            18.9         18.4
# 1      Alaska                    65            18.7         19.8
# 2     Arizona                    62            18.6         19.8
# 3    Arkansas                   100            18.9         19.0
# 4  California                    31            22.5         22.7
#
#    act_17_reading  act_17_science  act_17_composite
# 0            19.7            19.4              19.2
# 1            20.4            19.9              19.8
# 2            20.1            19.8              19.7
# 3            19.7            19.5              19.4
# 4            23.1            22.2              22.8

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
df_17 = pd.merge(df_act17, df_sat17, on='state')

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
file_name = './../data/combined_2017.csv'
df_17.to_csv(file_name)

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
df_sat18 = pd.read_csv('./../data/East_Coast_Data_Entry - SAT 2018.csv')
df_act18 = pd.read_csv('./../data/East_Coast_Data_Entry - ACT 2018.csv')

# %%
df_sat18.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            6%                                 595
# 1                Alaska           43%                                 562
# 2               Arizona           29%                                 577
# 3              Arkansas            5%                                 592
# 4            California           60%                                 540
# 5              Colorado           28%                                 519
# 6           Connecticut          100%                                 535
# 7              Delaware          100%                                 505
# 8  District of Columbia           92%                                 497
# 9               Florida           97%                                 522
#
#    Math  Total
# 0   571   1166
# 1   544   1106
# 2   572   1149
# 3   576   1168
# 4   536   1076
# 5   506   1025
# 6   519   1054
# 7   492    997
# ...

# %%
df_act18.head(10)
# Out:
#               State Participation  Composite
# 0           Alabama          100%       19.1
# 1            Alaska           33%       20.8
# 2           Arizona           66%       19.2
# 3          Arkansas          100%       19.4
# 4        California           27%       22.7
# 5          Colorado           30%       23.9
# 6       Connecticut           26%       25.6
# 7          Delaware           17%       23.8
# 8  Washington, D.C.           32%       23.6
# 9           Florida           66%       19.9

# %%
df_sat18.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
df_act18.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %% [markdown]
# So, similar to 2017 data sets, because of the % character, the values of the participation rate are cast into strings. In the following cells, I remove % and cast them into integers.

# %%
df_sat18['Participation'] = df_sat18['Participation'].map(lambda part_cell: part_cell.replace('%', ''))

df_sat18['Participation'] = df_sat18['Participation'].astype(int)

df_sat18['Participation'].dtypes
# Out:
# dtype('int64')

# %%
df_act18['Participation'] = df_act18['Participation'].map(lambda part_cell: part_cell.replace('%', ''))

df_act18['Participation'] = df_act18['Participation'].astype(int)

df_act18['Participation'].dtypes
# Out:
# dtype('int64')

# %%
# For the sake of consistency, in the ACT 2018 data set, I change the name of state from Washington D.C. to District
# of Columbia.

DC_index = df_act18[df_act18.State == 'Washington, D.C.'].index
df_act18.loc[DC_index, 'State'] = 'District of Columbia'
df_act18.head(10)
# Out:
#                   State  Participation  Composite
# 0               Alabama            100       19.1
# 1                Alaska             33       20.8
# 2               Arizona             66       19.2
# 3              Arkansas            100       19.4
# 4            California             27       22.7
# 5              Colorado             30       23.9
# 6           Connecticut             26       25.6
# 7              Delaware             17       23.8
# 8  District of Columbia             32       23.6
# 9               Florida             66       19.9

# %%
# Assigning new names to the columns of SAT 2018 and ACT 2018 data sets.

new_columns_sat18 = {
        'State':'state',
        'Participation':'sat_18_participation',
        'Evidence-Based Reading and Writing':'sat_18_reading_and_writing',
        'Math':'sat_18_math',
        'Total':'sat_18_total'
                    }

new_columns_act18 = {
        'State':'state',
        'Participation':'act_18_participation',
        'Composite':'act_18_composite'
                    }

df_sat18.rename(columns=new_columns_sat18, inplace=True)
df_act18.rename(columns=new_columns_act18, inplace=True)

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
df_18 = pd.merge(df_act18, df_sat18, on='state')
df_18.head()
# Out:
#         state  act_18_participation  act_18_composite  sat_18_participation  \
# 0     Alabama                   100              19.1                     6
# 1      Alaska                    33              20.8                    43
# 2     Arizona                    66              19.2                    29
# 3    Arkansas                   100              19.4                     5
# 4  California                    27              22.7                    60
#
#    sat_18_reading_and_writing  sat_18_math  sat_18_total
# 0                         595          571          1166
# 1                         562          544          1106
# 2                         577          572          1149
# 3                         592          576          1168
# 4                         540          536          1076

# %%
df = pd.merge(df_17, df_18, on='state')
df.head()
# Out:
#         state  act_17_participation  act_17_english  act_17_math  \
# 0     Alabama                   100            18.9         18.4
# 1      Alaska                    65            18.7         19.8
# 2     Arizona                    62            18.6         19.8
# 3    Arkansas                   100            18.9         19.0
# 4  California                    31            22.5         22.7
#
#    act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 0            19.7            19.4              19.2                     5
# 1            20.4            19.9              19.8                    38
# 2            20.1            19.8              19.7                    30
# 3            19.7            19.5              19.4                     3
# 4            23.1            22.2              22.8                    53
#
#    sat_17_reading_and_writing  sat_17_math  sat_17_total  \
# 0                         593          572          1165
# ...

# %%
file_name = './../data/final.csv'
df.to_csv(file_name)

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
df.describe().T
# Out:
#                             count         mean        std    min      25%  \
# act_17_participation         51.0    65.254902  32.140842    8.0    31.00
# act_17_english               51.0    20.931373   2.353677   16.3    19.00
# act_17_math                  51.0    21.182353   1.981989   18.0    19.40
# act_17_reading               51.0    22.013725   2.067271   18.1    20.45
# act_17_science               51.0    21.450980   1.739353   18.2    19.95
# act_17_composite             51.0    21.519608   2.020695   17.8    19.80
# sat_17_participation         51.0    39.803922  35.276632    2.0     4.00
# sat_17_reading_and_writing   51.0   569.117647  45.666901  482.0   533.50
# sat_17_math                  51.0   556.882353  47.121395  468.0   523.50
# sat_17_total                 51.0  1126.098039  92.494812  950.0  1055.50
# act_18_participation         51.0    61.725490  34.037085    7.0    28.50
# act_18_composite             51.0    21.496078   2.111583   17.7    19.95
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
def calc_std(vals):
    mean = sum(vals) / len(vals)
    diff = [(val - mean) ** 2 for val in vals]
    return ((1/len(vals)) * sum(diff)) ** 0.5

test = [1, 2, 3, 4]  # to test the function
calc_std(test)
# Out:
# 1.118033988749895

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
# Using manually defined function
sd = {column: calc_std(df[column].tolist()) for column in df.columns if df[column].dtype != 'O'}
sd
# Out:
# {'act_17_participation': 31.824175751231806,
#  'act_17_english': 2.3304876369363363,
#  'act_17_math': 1.9624620273436781,
#  'act_17_reading': 2.0469029314842646,
#  'act_17_science': 1.7222161451443676,
#  'act_17_composite': 2.000786081581989,
#  'sat_17_participation': 34.92907076664508,
#  'sat_17_reading_and_writing': 45.21697020437866,
#  'sat_17_math': 46.65713364485503,
#  'sat_17_total': 91.58351056778743,
#  'act_18_participation': 33.70173582041031,
#  'act_18_composite': 2.090779082141178,
#  'sat_18_participation': 36.93321382897817,
#  'sat_18_reading_and_writing': 44.864630427956726,
#  'sat_18_math': 48.97751133618255,
#  'sat_18_total': 93.51362961350053}

# %%
# Using Numpy standard deviation function
sd_numpy = {column: np.std(df[column].tolist()) for column in df.columns if df[column].dtype != 'O'}
sd_numpy
# Out:
# {'act_17_participation': 31.824175751231806,
#  'act_17_english': 2.3304876369363368,
#  'act_17_math': 1.9624620273436781,
#  'act_17_reading': 2.046902931484265,
#  'act_17_science': 1.7222161451443672,
#  'act_17_composite': 2.0007860815819893,
#  'sat_17_participation': 34.929070766645076,
#  'sat_17_reading_and_writing': 45.21697020437866,
#  'sat_17_math': 46.65713364485504,
#  'sat_17_total': 91.58351056778743,
#  'act_18_participation': 33.70173582041031,
#  'act_18_composite': 2.0907790821411782,
#  'sat_18_participation': 36.93321382897817,
#  'sat_18_reading_and_writing': 44.86463042795672,
#  'sat_18_math': 48.97751133618255,
#  'sat_18_total': 93.51362961350053}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer: The manually calculated standard deviations do not match up with the output of the describe method. Because in the calc_std function, the summation is divided by n, however, in Panda's describe standard devation is calculated by dividing the summation by n-1. In Numpy's std also the division by n is the default way of calculation the standard deviation.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
df.sort_values(by='sat_17_participation', ascending=False).head()
# Out:
#                    state  act_17_participation  act_17_english  act_17_math  \
# 8   District of Columbia                    32            24.4         23.5
# 22              Michigan                    29            24.1         23.7
# 6            Connecticut                    31            25.5         24.6
# 7               Delaware                    18            24.1         23.4
# 29         New Hampshire                    18            25.4         25.1
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 8             24.9            23.5              24.2                   100
# 22            24.5            23.8              24.1                   100
# 6             25.6            24.6              25.2                   100
# 7             24.8            23.6              24.1                   100
# 29            26.0            24.9              25.5                    96
#
# ...

# %% [markdown]
# D.C., Michigan, Connecticut, and Delaware have the highest participation rate (100%) is 2017 SAT.

# %%
df.sort_values(by='sat_17_participation').head()
# Out:
#            state  act_17_participation  act_17_english  act_17_math  \
# 34  North Dakota                    98            19.0         20.4
# 24   Mississippi                   100            18.2         18.1
# 15          Iowa                    67            21.2         21.3
# 25      Missouri                   100            19.8         19.9
# 44          Utah                   100            19.5         19.9
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 34            20.5            20.6              20.3                     2
# 24            18.8            18.8              18.6                     2
# 15            22.6            22.1              21.9                     2
# 25            20.8            20.5              20.4                     3
# 44            20.8            20.6              20.3                     3
#
#     sat_17_reading_and_writing  sat_17_math  sat_17_total  \
# ...

# %% [markdown]
# North Dakota, Mississippi, and Iowa have the lowest participation rate (2%) is 2017 SAT.

# %%
df.sort_values(by='act_17_participation', ascending=False).head(20)
# Out:
#              state  act_17_participation  act_17_english  act_17_math  \
# 0          Alabama                   100            18.9         18.4
# 17        Kentucky                   100            19.6         19.4
# 49       Wisconsin                   100            19.7         20.4
# 44            Utah                   100            19.5         19.9
# 42       Tennessee                   100            19.5         19.2
# 40  South Carolina                   100            17.5         18.6
# 36        Oklahoma                   100            18.5         18.8
# 33  North Carolina                   100            17.8         19.3
# 28          Nevada                   100            16.3         18.0
# 26         Montana                   100            19.0         20.2
# 24     Mississippi                   100            18.2         18.1
# 23       Minnesota                   100            20.4         21.5
# ...

# %% [markdown]
# 17 states as indicated above have the highest participation rate (100%) in 2017 ACT.

# %%
df.sort_values(by='act_17_participation').head()
# Out:
#             state  act_17_participation  act_17_english  act_17_math  \
# 19          Maine                     8            24.2         24.0
# 29  New Hampshire                    18            25.4         25.1
# 7        Delaware                    18            24.1         23.4
# 39   Rhode Island                    21            24.0         23.3
# 38   Pennsylvania                    23            23.4         23.4
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 19            24.8            23.7              24.3                    95
# 29            26.0            24.9              25.5                    96
# 7             24.8            23.6              24.1                   100
# 39            24.7            23.4              24.0                    71
# 38            24.2            23.3              23.7                    65
#
#     sat_17_reading_and_writing  sat_17_math  sat_17_total  \
# ...

# %% [markdown]
# Maine has the lowest participation rate (8%) in 2017 ACT.

# %%
df.sort_values(by='sat_18_participation', ascending=False).head()
# Out:
#           state  act_17_participation  act_17_english  act_17_math  \
# 22     Michigan                    29            24.1         23.7
# 6   Connecticut                    31            25.5         24.6
# 7      Delaware                    18            24.1         23.4
# 12        Idaho                    38            21.9         21.8
# 19        Maine                     8            24.2         24.0
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 22            24.5            23.8              24.1                   100
# 6             25.6            24.6              25.2                   100
# 7             24.8            23.6              24.1                   100
# 12            23.0            22.1              22.3                    93
# 19            24.8            23.7              24.3                    95
#
#     sat_17_reading_and_writing  sat_17_math  sat_17_total  \
# ...

# %%
df.sort_values(by='sat_18_participation').head()
# Out:
#            state  act_17_participation  act_17_english  act_17_math  \
# 34  North Dakota                    98            19.0         20.4
# 50       Wyoming                   100            19.4         19.8
# 41  South Dakota                    80            20.7         21.5
# 27      Nebraska                    84            20.9         20.9
# 49     Wisconsin                   100            19.7         20.4
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 34            20.5            20.6              20.3                     2
# 50            20.8            20.6              20.2                     3
# 41            22.3            22.0              21.8                     3
# 27            21.9            21.5              21.4                     3
# 49            20.6            20.9              20.5                     3
#
#     sat_17_reading_and_writing  sat_17_math  sat_17_total  \
# ...

# %%
df.sort_values(by='act_18_participation', ascending=False).head(20)
# Out:
#              state  act_17_participation  act_17_english  act_17_math  \
# 0          Alabama                   100            18.9         18.4
# 17        Kentucky                   100            19.6         19.4
# 49       Wisconsin                   100            19.7         20.4
# 44            Utah                   100            19.5         19.9
# 42       Tennessee                   100            19.5         19.2
# 40  South Carolina                   100            17.5         18.6
# 36        Oklahoma                   100            18.5         18.8
# 35            Ohio                    75            21.2         21.6
# 33  North Carolina                   100            17.8         19.3
# 28          Nevada                   100            16.3         18.0
# 27        Nebraska                    84            20.9         20.9
# 26         Montana                   100            19.0         20.2
# ...

# %%
df.sort_values(by='act_18_participation').head()
# Out:
#             state  act_17_participation  act_17_english  act_17_math  \
# 19          Maine                     8            24.2         24.0
# 39   Rhode Island                    21            24.0         23.3
# 29  New Hampshire                    18            25.4         25.1
# 7        Delaware                    18            24.1         23.4
# 38   Pennsylvania                    23            23.4         23.4
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 19            24.8            23.7              24.3                    95
# 39            24.7            23.4              24.0                    71
# 29            26.0            24.9              25.5                    96
# 7             24.8            23.6              24.1                   100
# 38            24.2            23.3              23.7                    65
#
#     sat_17_reading_and_writing  sat_17_math  sat_17_total  \
# ...

# %%
df.sort_values(by='sat_17_total', ascending=False).head()
# Out:
#         state  act_17_participation  act_17_english  act_17_math  \
# 23  Minnesota                   100            20.4         21.5
# 49  Wisconsin                   100            19.7         20.4
# 15       Iowa                    67            21.2         21.3
# 25   Missouri                   100            19.8         19.9
# 16     Kansas                    73            21.1         21.3
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 23            21.8            21.6              21.5                     3
# 49            20.6            20.9              20.5                     3
# 15            22.6            22.1              21.9                     2
# 25            20.8            20.5              20.4                     3
# 16            22.3            21.7              21.7                     4
#
#     sat_17_reading_and_writing  sat_17_math  sat_17_total  \
# 23                         644          651          1295
# ...

# %%
df.sort_values(by='sat_17_total').head()
# Out:
#                    state  act_17_participation  act_17_english  act_17_math  \
# 8   District of Columbia                    32            24.4         23.5
# 7               Delaware                    18            24.1         23.4
# 12                 Idaho                    38            21.9         21.8
# 22              Michigan                    29            24.1         23.7
# 19                 Maine                     8            24.2         24.0
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 8             24.9            23.5              24.2                   100
# 7             24.8            23.6              24.1                   100
# 12            23.0            22.1              22.3                    93
# 22            24.5            23.8              24.1                   100
# 19            24.8            23.7              24.3                    95
#
# ...

# %%
df.sort_values(by='act_17_composite', ascending=False).head()
# Out:
#                    state  act_17_participation  act_17_english  act_17_math  \
# 29         New Hampshire                    18            25.4         25.1
# 21         Massachusetts                    29            25.4         25.3
# 6            Connecticut                    31            25.5         24.6
# 19                 Maine                     8            24.2         24.0
# 8   District of Columbia                    32            24.4         23.5
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 29            26.0            24.9              25.5                    96
# 21            25.9            24.7              25.4                    76
# 6             25.6            24.6              25.2                   100
# 19            24.8            23.7              24.3                    95
# 8             24.9            23.5              24.2                   100
#
# ...

# %%
df.sort_values(by='act_17_composite').head()
# Out:
#              state  act_17_participation  act_17_english  act_17_math  \
# 28          Nevada                   100            16.3         18.0
# 24     Mississippi                   100            18.2         18.1
# 40  South Carolina                   100            17.5         18.6
# 11          Hawaii                    90            17.8         19.2
# 33  North Carolina                   100            17.8         19.3
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 28            18.1            18.2              17.8                    26
# 24            18.8            18.8              18.6                     2
# 40            19.1            18.9              18.7                    50
# 11            19.2            19.3              19.0                    55
# 33            19.6            19.3              19.1                    49
#
#     sat_17_reading_and_writing  sat_17_math  sat_17_total  \
# ...

# %%
df.sort_values(by='sat_18_total', ascending=False).head()
# Out:
#            state  act_17_participation  act_17_english  act_17_math  \
# 23     Minnesota                   100            20.4         21.5
# 49     Wisconsin                   100            19.7         20.4
# 34  North Dakota                    98            19.0         20.4
# 25      Missouri                   100            19.8         19.9
# 15          Iowa                    67            21.2         21.3
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 23            21.8            21.6              21.5                     3
# 49            20.6            20.9              20.5                     3
# 34            20.5            20.6              20.3                     2
# 25            20.8            20.5              20.4                     3
# 15            22.6            22.1              21.9                     2
#
#     sat_17_reading_and_writing  sat_17_math  sat_17_total  \
# ...

# %%
df.sort_values(by='sat_18_total').head()
# Out:
#                    state  act_17_participation  act_17_english  act_17_math  \
# 8   District of Columbia                    32            24.4         23.5
# 7               Delaware                    18            24.1         23.4
# 48         West Virginia                    69            20.0         19.4
# 12                 Idaho                    38            21.9         21.8
# 22              Michigan                    29            24.1         23.7
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 8             24.9            23.5              24.2                   100
# 7             24.8            23.6              24.1                   100
# 48            21.2            20.5              20.4                    14
# 12            23.0            22.1              22.3                    93
# 22            24.5            23.8              24.1                   100
#
# ...

# %%
df.sort_values(by='act_18_composite', ascending=False).head()
# Out:
#             state  act_17_participation  act_17_english  act_17_math  \
# 6     Connecticut                    31            25.5         24.6
# 21  Massachusetts                    29            25.4         25.3
# 29  New Hampshire                    18            25.4         25.1
# 32       New York                    31            23.8         24.0
# 22       Michigan                    29            24.1         23.7
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 6             25.6            24.6              25.2                   100
# 21            25.9            24.7              25.4                    76
# 29            26.0            24.9              25.5                    96
# 32            24.6            23.9              24.2                    67
# 22            24.5            23.8              24.1                   100
#
#     sat_17_reading_and_writing  sat_17_math  sat_17_total  \
# ...

# %%
df.sort_values(by='act_18_composite').head()
# Out:
#              state  act_17_participation  act_17_english  act_17_math  \
# 28          Nevada                   100            16.3         18.0
# 40  South Carolina                   100            17.5         18.6
# 24     Mississippi                   100            18.2         18.1
# 11          Hawaii                    90            17.8         19.2
# 0          Alabama                   100            18.9         18.4
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 28            18.1            18.2              17.8                    26
# 40            19.1            18.9              18.7                    50
# 24            18.8            18.8              18.6                     2
# 11            19.2            19.3              19.0                    55
# 0             19.7            19.4              19.2                     5
#
#     sat_17_reading_and_writing  sat_17_math  sat_17_total  \
# ...

# %%
mask_part = (df['sat_17_participation'] == 100) & (df['sat_18_participation'] != 100)
df[mask_part]
# Out:
#                   state  act_17_participation  act_17_english  act_17_math  \
# 8  District of Columbia                    32            24.4         23.5
#
#    act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 8            24.9            23.5              24.2                   100
#
#    sat_17_reading_and_writing  sat_17_math  sat_17_total  \
# 8                         482          468           950
#
#    act_18_participation  act_18_composite  sat_18_participation  \
# 8                    32              23.6                    92
#
#    sat_18_reading_and_writing  sat_18_math  sat_18_total
# 8                         497          480           977

# %%
mask_part = (df['sat_18_participation'] == 100) & (df['sat_17_participation'] != 100)
df[mask_part]
# Out:
#     state  act_17_participation  act_17_english  act_17_math  act_17_reading  \
# 12  Idaho                    38            21.9         21.8            23.0
#
#     act_17_science  act_17_composite  sat_17_participation  \
# 12            22.1              22.3                    93
#
#     sat_17_reading_and_writing  sat_17_math  sat_17_total  \
# 12                         513          493          1005
#
#     act_18_participation  act_18_composite  sat_18_participation  \
# 12                    36              22.3                   100
#
#     sat_18_reading_and_writing  sat_18_math  sat_18_total
# 12                         508          493          1001

# %%
mask_part = (df['act_17_participation'] == 100) & (df['act_18_participation'] != 100)
df[mask_part]
# Out:
#         state  act_17_participation  act_17_english  act_17_math  \
# 5    Colorado                   100            20.1         20.3
# 23  Minnesota                   100            20.4         21.5
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 5             21.2            20.9              20.8                    11
# 23            21.8            21.6              21.5                     3
#
#     sat_17_reading_and_writing  sat_17_math  sat_17_total  \
# 5                          606          595          1201
# 23                         644          651          1295
#
#     act_18_participation  act_18_composite  sat_18_participation  \
# 5                     30              23.9                    28
# 23                    99              21.3                     4
#
#     sat_18_reading_and_writing  sat_18_math  sat_18_total
# 5                          519          506          1025
# ...

# %%
mask_part = (df['act_18_participation'] == 100) & (df['act_17_participation'] != 100)
df[mask_part]
# Out:
#        state  act_17_participation  act_17_english  act_17_math  \
# 27  Nebraska                    84            20.9         20.9
# 35      Ohio                    75            21.2         21.6
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 27            21.9            21.5              21.4                     3
# 35            22.5            22.0              22.0                    12
#
#     sat_17_reading_and_writing  sat_17_math  sat_17_total  \
# 27                         629          625          1253
# 35                         578          570          1149
#
#     act_18_participation  act_18_composite  sat_18_participation  \
# 27                   100              20.1                     3
# 35                   100              20.3                    18
#
#     sat_18_reading_and_writing  sat_18_math  sat_18_total
# 27                         629          623          1252
# ...

# %%
mask_part = (df['sat_17_participation'] > 50) & (df['act_17_participation'] > 50)
df[mask_part]
# Out:
#       state  act_17_participation  act_17_english  act_17_math  \
# 9   Florida                    73            19.0         19.4
# 10  Georgia                    55            21.0         20.9
# 11   Hawaii                    90            17.8         19.2
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 9             21.0            19.4              19.8                    83
# 10            22.0            21.3              21.4                    61
# 11            19.2            19.3              19.0                    55
#
#     sat_17_reading_and_writing  sat_17_math  sat_17_total  \
# 9                          520          497          1017
# 10                         535          515          1050
# 11                         544          541          1085
#
#     act_18_participation  act_18_composite  sat_18_participation  \
# 9                     66              19.9                    97
# ...

# %%
mask_part = (df['sat_18_participation'] > 50) & (df['act_18_participation'] >50)
df[mask_part]
# Out:
#              state  act_17_participation  act_17_english  act_17_math  \
# 9          Florida                    73            19.0         19.4
# 10         Georgia                    55            21.0         20.9
# 11          Hawaii                    90            17.8         19.2
# 33  North Carolina                   100            17.8         19.3
# 40  South Carolina                   100            17.5         18.6
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 9             21.0            19.4              19.8                    83
# 10            22.0            21.3              21.4                    61
# 11            19.2            19.3              19.0                    55
# 33            19.6            19.3              19.1                    49
# 40            19.1            18.9              18.7                    50
#
#     sat_17_reading_and_writing  sat_17_math  sat_17_total  \
# ...

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
plt.figure(figsize=(14, 14))

sns.heatmap(df.corr(), cmap='Reds')
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.title("Correlation between scores and participation rates\nin SAT and ACT exams conducted in 2017 and 2018", fontsize = 25);

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough row
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(12, 6)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) 
        ax[i].set_title(list_of_titles[i], fontsize=20)
        ax[i].set_xlabel(list_of_xlabels[i], fontsize=15)
        ax[i].tick_params(labelsize=15)

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
columns = ['sat_17_participation', 'act_17_participation']
titles = ['Participation rate for SAT 2017', 'Participation rate for ACT 2017']
xlabels = ['Participation (%)', 'Participation (%)']
subplot_histograms(df, columns, titles, xlabels)

# %% [markdown]
# In case of SAT 2017, the histogram is heavily skewed to the left which means very low participation rate for a large number (20+) of states. However, for ACT 2017, the plot skewness is to the right which means a pretty large number of states have adopted the ACT exam. There is also a peak around 30% which probably indicates the states which are transitioning to the ACT exam.

# %%
columns = ['sat_18_participation', 'act_18_participation']
titles = ['Participation rate for SAT 2018', 'Participation rate for ACT 2018']
xlabels = ['Participation (%)', 'Participation (%)']
subplot_histograms(df, columns, titles, xlabels)

# %% [markdown]
# In case of SAT 2018, still we have peak on the left side, although with a lower number (around 17) compared to 2017. There is another peak on the right side of the histogram which shows ample growth compared to 2017. This is probably due to some states which traditionally used to take ACT and now they have transitioned to the SAT exam. In case of the ACT 2018, the peak on the right side remains the same, however, this time we see more flattened peaks in the middle which could be related to new states adopting the ACT exam.

# %%
columns = ['sat_17_math', 'act_17_math']
titles = ['Math score for SAT 2017', 'Math score for ACT 2017']
xlabels = ['Math score', 'Math score']
subplot_histograms(df, columns, titles, xlabels)

# %% [markdown]
# The math score for SAT 2017 has a peak almost in the middle (around score 530) which around the national average (527). The other scores, to some extent, are uniformly distributed (except the highest and lowest scores). IN case of math score for ACT 2017, there are sebveral peaks around scores 19, 21, and 23. Compared to SAt scores, here the scores are realatively more uniformly distributed.

# %%
columns = ['sat_17_reading_and_writing', 'act_17_reading']
titles = ['Reading score for SAT 2017', 'Reading score for ACT 2017']
xlabels = ['Reading score', 'Reading score']
subplot_histograms(df, columns, titles, xlabels)

# %% [markdown]
# The histogram of reading scores for the SAT 2017 shows that there is a large peak arounf the score 530 (close to the national average) and another one at the right end of the spectrum. So, the states are either grouped around the national average or around the highest score. For the case of ACT 2017, the graph shows two peak in the range of 20-21 and some other local peaks. Here, the spread of score seems to be higher than the case of SAT scores.

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
# Function defined to plot scatter graphs

def plot_scatter(dataframe, list_of_columns, title, list_of_labels):
    plt.figure(figsize=(8, 5))
    sns.scatterplot(dataframe[list_of_columns[0]], dataframe[list_of_columns[1]], s=100)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.xlabel(list_of_labels[0], fontsize=15)
    plt.ylabel(list_of_labels[1], fontsize=15)
    plt.title(title, fontsize=20)

# %%
columns = ['sat_17_math', 'act_17_math']
title = 'SAT vs. ACT math scores for 2017'
labels = ['SAT math score', 'ACT math score']
plot_scatter(df, columns, title, labels)

# %% [markdown]
# The graph shows a scattered pattern, so no reliable conclusion can be drawn regarding the relationship between math scores of SAT and ACT exams in 2017.

# %%
columns = ['sat_17_reading_and_writing', 'act_17_reading']
title = 'SAT vs. ACT verbal/reading scores for 2017'
labels = ['SAT reading & writing score', 'ACT reading score']
plot_scatter(df, columns, title, labels)

# %% [markdown]
# Again, the data look very scattered and it's difficult to come by any particular pattern.

# %%
columns = ['sat_17_total', 'act_17_composite']
title = 'SAT vs. ACT total/composite scores for 2017'
labels = ['SAT total score', 'ACT composite score']
plot_scatter(df, columns, title, labels)

# %% [markdown]
# Here, the data look scattered too and the points do not aggregate along a particular curve/line.

# %%
columns = ['sat_17_total', 'sat_18_total']
title = 'Total scores for SAT 2017 vs. 2018'
labels = ['SAT total score (2017)', 'SAT total score (2018)']
plot_scatter(df, columns, title, labels)

# %% [markdown]
# Looking at this scattered plot, it seems that there is a linear relationship between total scores of the SAT esxam conducted in 2017 and 2018. The slope of this line, more or less, seems to be close to 1.

# %%
columns = ['act_17_composite', 'act_18_composite']
title = 'Composite scores for ACT 2017 vs. 2018'
labels = ['ACT composite score (2017)', 'ACT composite score (2018)']
plot_scatter(df, columns, title, labels)

# %% [markdown]
# Again, it seems that there is a linear relationship between composite scores of the ACT exam conducted in 2017 and 2018 and the slope of this line seems to be around 1.

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
plt.figure(figsize=(20, 5))

plt.subplot(131)
sns.boxplot(data=[df.sat_17_math, df.sat_18_math])
plt.yticks(fontsize=15)
plt.xticks(np.arange(2), ('SAT Math 2017', 'SAT Math 2018'), fontsize=15)
plt.title('Distribution of SAT Math Scores', fontsize=20)

plt.subplot(132)
sns.boxplot(data=[df.sat_17_reading_and_writing, df.sat_18_reading_and_writing])
plt.yticks(fontsize=15)
plt.xticks(np.arange(2), ('SAT Reading 2017', 'SAT Reading 2018'), fontsize=15)
plt.title('Distribution of SAT Reading Scores', fontsize=20)

plt.subplot(133)
sns.boxplot(data=[df.sat_17_total, df.sat_18_total])
plt.yticks(fontsize=15)
plt.xticks(np.arange(2), ('SAT Total 2017', 'SAT Total 2018'), fontsize=15)
plt.title('Distribution of SAT Total Scores', fontsize=20);

# %%
plt.figure(figsize=(8, 8))

sns.boxplot(data=[df.act_17_english, df.act_17_math, df.act_17_reading, df.act_17_science])
plt.yticks(fontsize=15)
plt.ylabel('Score', fontsize=18)
plt.xticks(np.arange(4), ('English', 'Math', 'Reading', 'Science'), fontsize=15)
plt.title('Distribution of ACT Scores (2017)', fontsize=20);

# %%
plt.figure(figsize=(7, 7))

sns.boxplot(data=[df.act_17_composite, df.act_18_composite])
plt.yticks(fontsize=15)
plt.ylabel('Score', fontsize=18)
plt.xticks(np.arange(2), ('ACT Composite 2017', 'ACT Composite 2018'), fontsize=15)
plt.title('Distribution of ACT Composite Scores\nfor 2017 and 2018', fontsize=20);

# %%
plt.figure(figsize=(9, 9))

sns.boxplot(data=[df.sat_17_participation, df.sat_18_participation, df.act_17_participation, df.act_18_participation])
plt.yticks(fontsize=15)
plt.ylabel('Participation (%)', fontsize=18)
plt.xticks(np.arange(4), ('SAT 2017', 'SAT 2018', 'ACT 2017', 'ACT 2018'), fontsize=15)
plt.title('Distribution of participation in SAT and ACT exams\nfor 2017 and 2018', fontsize=20);

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
df['sat_participation_diff'] = ((df.sat_18_participation - df.sat_17_participation) / df.sat_17_participation) * 100

df['act_participation_diff'] = ((df.act_18_participation - df.act_17_participation) / df.act_17_participation) * 100

sat_index = df.sat_participation_diff.abs().sort_values(ascending=False).index
sat_index = sat_index[0:5]

act_index = df.act_participation_diff.abs().sort_values(ascending=False).index
act_index = act_index[0:5]

plt.figure(figsize=(18, 6))

plt.subplot(121)
plt.bar(df.loc[sat_index, 'state'], df.loc[sat_index, 'sat_participation_diff'])
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.title('Percentage of change in partcipation rate\nin SAT exam in 2018 compared to 2017', fontsize=20)

plt.subplot(122)
plt.bar(df.loc[act_index, 'state'], df.loc[act_index, 'act_participation_diff'])
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.title('Percentage of change in partcipation rate\nin ACT exam in 2018 compared to 2017', fontsize=20);

# %% [markdown]
# These graphs demonstrate 5 states with steepest rate of change (growth/decline) in participation in 2018 compared to 2017 for the SAT (left) and ACT (right) exams. The huge growth in participation rate in SAT in Illinois and Colorado seems very interesting. These two states show a reverse behavior (decrease in participation rate) in the ACT exam.

# %%
df['sat_total_diff'] = ((df.sat_18_total - df.sat_17_total) / df.sat_17_total) * 100

df['act_composite_diff'] = ((df.act_18_composite - df.act_17_composite) / df.act_17_composite) * 100

sat_index = df.sat_total_diff.abs().sort_values(ascending=False).index
sat_index = sat_index[0:5]

act_index = df.act_composite_diff.abs().sort_values(ascending=False).index
act_index = act_index[0:5]

plt.figure(figsize=(15, 6))

plt.subplot(121)
plt.bar(df.loc[sat_index, 'state'], df.loc[sat_index, 'sat_total_diff'])
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.title('Percentage of change in\ntotal score in SAT exam', fontsize=20)

plt.subplot(122)
plt.bar(df.loc[act_index, 'state'], df.loc[act_index, 'act_composite_diff'])
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.title('Percentage of change in\ncomposite score in ACT exam', fontsize=20);

# %% [markdown]
# These graphs demonstrate 5 states with steepest rate of change (growth/decline) in total/composite scores in 2018 compared to 2017 for the SAT (left) and ACT (right) exams. Colorado and Illinois demonstrate the highest descline in the average total scores in the SAT exam. The same two states also display the highest growth in the composite score of the ACT exam.

# %%
plt.figure(figsize=(20, 6))

plt.subplot(121)
plt.scatter(df.sat_17_participation, df.sat_17_total, marker='o', s=100)
plt.scatter(df.sat_18_participation, df.sat_18_total, marker='^', s=100)
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)
plt.xlabel('Participation rate', fontsize=20)
plt.ylabel('Total score', fontsize=20)
plt.legend(['2017', '2018'], fontsize=20, edgecolor='black')
plt.title('Participation rate vs. Total score for SAT\n', fontsize=24)

plt.subplot(122)
plt.scatter(df.act_17_participation, df.act_17_composite, marker='o', s=100)
plt.scatter(df.act_18_participation, df.act_18_composite, marker='^', s=100)
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)
plt.xlabel('Participation rate', fontsize=20)
plt.ylabel('Composite score', fontsize=20)
plt.legend(['2017', '2018'], fontsize=20, edgecolor='black')
plt.title('Participation rate vs. Composite score for ACT\n', fontsize=24);

# %% [markdown]
# The above graphs show that, on average, in both SAT and ACT exams the total/composite score is negatively correlated to the participation rate. In other words, the higher the participation rate the lower the average total score and vice versa. This explains why some states which have undergone a rapid growth in participation in either of these exams experience a drop in their average total score.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# <h3><center>Participation rate in SAT 2017</center></h3>
#
# ![](./../Images/SAT_17_participation.png)
#
# <h3><center>Participation rate in SAT 2018</center></h3>
#
# ![](./../Images/SAT_18_participation.png)
#
# <h3><center>Participation rate in ACT 2017</center></h3>
#
# ![](./../Images/ACT_17_participation.png)
#
# <h3><center>Participation rate in ACT 2018</center></h3>
#
# ![](./../Images/ACT_18_participation.png)

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# Answers:
#
# * Participation in ACT 2017: The average participation rate is about 65% (median 69%) with a standard deviation of about 32%. The data is skewed to the left and it is not normally distributed.
#
# * Participation in SAT 2017: The average participation rate is about 40% (median 38%) with a standard deviation of about 35%. The data is skewed to the left and it is not completely represent a normal distribution.
#
# * Participation in ACT 2018: The average participation rate is about 62% (median 66%) with a standard deviation of about 34%. There are two major peaks in the data and so it is not normally distributed.
#
# * Participation in SAT 2018: The average participation rate is about 45% (median 48%) with a standard deviation of about 37%. There are two major peaks in the data and so it is not normally distributed.
#
# * Composite score of ACT 2017: The average composite score is about 21.5 (median 21.4) with a standard deviation of about 2.02. The data is a bit skewed to the left.
#
# * Total score of SAT 2017: The average total score is about 1126 (median 1107) with a standard deviation of about 92. The data is skewed to the left and so it is not normally distributed.
#
# * Composite score of ACT 2018: The average composite score is about 21.5 (median 21.3) with a standard deviation of about 2.11. The data is a bit skewed to the left.
#
# * Total score of SAT 2018: The average total score is about 1126 (median 1099) with a standard deviation of about 94. The data is skewed to the left and so it is not normally distributed.

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer: Not for many of the distributions as described above. The distribution of scores within each state is most probably normal because they are based on a large sample. But considering relatively small number of states (51) and different factors in each state (different particiaption rates, different educational background, etc), comparing different states does not yield a normal distribution.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer: As stated above, none of these distributions really represent a normal distribution. If we plot these distributions using `sns.distplot` we can quickly realize that the data are usually skewed and we cannot apply the central limit theorem to the samples of these distribution unless the sample size encompasses at least more that 30 states.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer: Looking at the following scatter plot, it seems that participation rate in ACT exam has a inverse relationship with that of the SAT exam, i.e. the higher the participation in ACT the lower participation in SAT and vice versa. Although the data points are grouped along a line, but probably we can use some kind of regression model to find their relationship.

# %%
columns = ['act_17_participation', 'sat_17_participation']
title = 'Participation rate for ACT vs. SAT in 2017'
labels = ['ACT participation (2017)', 'SAT participation (2017)']
plot_scatter(df, columns, title, labels)

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer: No, because the method of grading, the number of participants, the level of hardness, the method used for normalizing the scores, ... is different for these exams. So, comparing math scores of these tests probably does not yield statistically meaningful results.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# I am inclined to choose these states: **Colorado**, **Illinois**, and **West Virginia**
# The reason is that these states demonstrate the highest rate of growth in the participation rate in SAT 2018 and the steepest rate of decline in SAT 2018 average total score. The first two states also represent the steepest drop in participation and the highest growth in the average composite score of the ACT exam conducted in 2018.
#
# In case of Illinois, the Illinois High School Accountability Assessments in June 2018 made a contract with College Board, which administers the SAT, to expand their duties as the state’s official tester over ACT (see [here](https://www.ilnews.org/news/schools/college-exam-company-raises-questions-about-with-illinois-act-sat/article_c4a805ca-8b93-11e8-b9d4-f7ab2c28ae00.html)). Although the fairness of this contract has raised many questions, but this is the approved policy in Illinois so far and the majority of juniors in that state took the SAT exam this year. This rapid transition to this new system of standardized tests is probably the main reason behind 8% drop in the average score of the SAT exam. However, some experts have blamed the teacher shortage for the low sclores (see [here](https://chalkbeat.org/posts/chicago/2018/09/12/teacher-shortage-blamed-as-fewer-illinois-sat-pass-rates-decline-parcc-scores-flatten/)).
#
# In Colorado, in 2016, the state Department of Education chose the College Board, makers of the SAT, over the ACT testing company to conduct the standardized test (see [here](https://chalkbeat.org/posts/co/2015/12/23/goodbye-act-hello-sat-a-significant-change-for-colorado-high-schoolers/)). Juniors took the SAT for the first time in 2017 as a mandatory state test (see [here](https://www.chalkbeat.org/posts/co/2017/08/17/sat-scores-show-mixed-results-on-whether-colorado-juniors-are-on-track-for-college/)). It seems that Colorado is gradually transitioning from ACT to SAT exam and each year the number of students taking the SAT exam will grow compared to the year before. It is likely that 15% drop in the average score of the SAT exam is due to the fact that this year the number of participants is more than doubled and these new students have a more diverse educational background, ethnicity, etc. So, the new average better reflects the average literacy level of students across the entire state.
#
# West Virginia is the other key battle the ACT company has lost to the College Board. In 2017, the West Virginia Department of Education chose the SAT as the new statewide standardized test to replace the Smarter Balanced exam for high school juniors (see [here](https://www.wvgazettemail.com/news/education/wv-chooses-sat-as-new-high-school-standardized-test-for/article_b60d2618-4943-56f6-b180-4b4442172ef8.html)). According to Charlestone Gazette Mail, "This is the first time, at least in recent years, that a popular college-entrance exam will be given to most West Virginia public school students for free". Similar to Colorado, a more diversified population of students taking the SAT test is probably responsible for about 8% drop in the average score of this exam in 2018.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# The states which have decided to adopt a new platform of standardized tests should allow for a smooth transition from the old system to the new system in order the educators and the students be able to adapt themselves gradually. Otherwise, a big jump in the participation rate of either of these exams will only deteriorate the average score of that state and it may result in a distrust of the new platform.
